# %%
import numpy as np
import matplotlib.pyplot as plt
from src import gaussian
from src import cart2pol
from src import pol2cart
from src import calc_score_phi


idx = calc_score_phi(2*np.pi)

phi = np.linspace(0,360,100)*np.pi/180
sc = np.zeros_like(phi)
for i in range(len(phi)):
    sc[i] = calc_score_phi(phi[i])

plt.plot(phi*180/np.pi,sc,'x')
plt.grid()
